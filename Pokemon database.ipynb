# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/divya/Downloads/Pokemon.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
 df.head(15)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.shape
# Out:
# (800, 13)

# %%
df.shape[0]
# Out:
# 800

# %%
df.shape[1]
# Out:
# 13

# %%
print(f'row:{df.shape[0]}')
print(f'columns:{df.shape[1]}')
# Out:
# row:800
# columns:13

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# read headers
cols = list(df.columns)
print(cols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %% [markdown]
# # sorting/descrribing data

# %%
df = df.sort_values(['Type 1', 'HP'], ascending = [0,1])

# %%
df
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 139  129                 Magikarp  Water       NaN    200  20      10
# 381  349                   Feebas  Water       NaN    200  20      15
# 97    90                 Shellder  Water       NaN    305  30      65
# 106   98                   Krabby  Water       NaN    325  30     105
# 125  116                   Horsea  Water       NaN    295  30      40
# ..   ...                      ...    ...       ...    ...  ..     ...
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# 734  666                 Vivillon    Bug    Flying    411  80      52
# 698  637                Volcarona    Bug      Fire    550  85      60
# 520  469                  Yanmega    Bug    Flying    515  86      76
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 139       55       15       20     80           1      False
# ...

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 139  129  Magikarp  Water    NaN    200  20      10       55       15
# 381  349    Feebas  Water    NaN    200  20      15       20       10
# 97    90  Shellder  Water    NaN    305  30      65      100       45
# 106   98    Krabby  Water    NaN    325  30     105       90       25
# 125  116    Horsea  Water    NaN    295  30      40       70       70
#
#      Sp. Def  Speed  Generation  Legendary
# 139       20     80           1      False
# 381       55     80           3      False
# 97        25     40           1      False
# 106       25     50           1      False
# 125       25     60           1      False

# %% [markdown]
# # making changes to the data

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
#df = df.drop(cloumns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:-1]]

# %%
df.head(5)
# Out:
#        #      Name Type 1 Type 2  Legendary  Total  HP  Attack  Defense  \
# 139  129  Magikarp  Water    NaN      False    320  20      10       55
# 381  349    Feebas  Water    NaN      False    320  20      15       20
# 97    90  Shellder  Water    NaN      False    570  30      65      100
# 106   98    Krabby  Water    NaN      False    600  30     105       90
# 125  116    Horsea  Water    NaN      False    530  30      40       70
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 139       15       20     80           1
# 381       10       55     80           3
# 97        45       25     40           1
# 106       25       25     50           1
# 125       70       25     60           1

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df['new-total'] = df.iloc[:, 4:10].sum(axis=1)

# %%
df
# Out:
#        #                     Name Type 1    Type 2  Legendary  Total  HP  \
# 139  129                 Magikarp  Water       NaN      False    200  20
# 381  349                   Feebas  Water       NaN      False    200  20
# 97    90                 Shellder  Water       NaN      False    305  30
# 106   98                   Krabby  Water       NaN      False    325  30
# 125  116                   Horsea  Water       NaN      False    295  30
# ..   ...                      ...    ...       ...        ...    ...  ..
# 232  214  HeracrossMega Heracross    Bug  Fighting      False    600  80
# 678  617                 Accelgor    Bug       NaN      False    495  80
# 734  666                 Vivillon    Bug    Flying      False    411  80
# 698  637                Volcarona    Bug      Fire      False    550  85
# 520  469                  Yanmega    Bug    Flying      False    515  86
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation new-total
# ...

# %%
 df.drop(['new-total'], axis=1)
# Out:
#        #                     Name Type 1    Type 2  Legendary  Total  HP  \
# 139  129                 Magikarp  Water       NaN      False    200  20
# 381  349                   Feebas  Water       NaN      False    200  20
# 97    90                 Shellder  Water       NaN      False    305  30
# 106   98                   Krabby  Water       NaN      False    325  30
# 125  116                   Horsea  Water       NaN      False    295  30
# ..   ...                      ...    ...       ...        ...    ...  ..
# 232  214  HeracrossMega Heracross    Bug  Fighting      False    600  80
# 678  617                 Accelgor    Bug       NaN      False    495  80
# 734  666                 Vivillon    Bug    Flying      False    411  80
# 698  637                Volcarona    Bug      Fire      False    550  85
# 520  469                  Yanmega    Bug    Flying      False    515  86
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
type([cols[-1]])
# Out:
# list

# %%
cols[0:4] + [cols[-1]]+cols[4:-1]
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Legendary',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation']

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Legendary       0
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# new-total       0
# dtype: int64

# %%
cat_col = ['Name',
           'Type 1',
           'Type 2']
cat_col
# Out:
# ['Name', 'Type 1', 'Type 2']

# %%
for col in cat_col:
    print(col)
    print(df[col].value_counts())
# Out:
# Name
# Name
# Magikarp      1
# Magcargo      1
# Noivern       1
# Vulpix        1
# Charmander    1
#              ..
# Doduo         1
# Sentret       1
# Zigzagoon     1
# Bunnelby      1
# Yanmega       1
# Name: count, Length: 800, dtype: int64
# Type 1
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64
# Type 2
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ghost       14
# Rock        14
# Ice         14
# Water       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Legendary       bool
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# new-total     object
# dtype: object

# %%
df.mode()
# Out:
#          #                     Name Type 1  Type 2 Legendary  Total    HP  \
# 0    479.0                Abomasnow  Water  Flying     False  600.0  60.0
# 1      NaN  AbomasnowMega Abomasnow    NaN     NaN       NaN    NaN   NaN
# 2      NaN                     Abra    NaN     NaN       NaN    NaN   NaN
# 3      NaN                    Absol    NaN     NaN       NaN    NaN   NaN
# 4      NaN          AbsolMega Absol    NaN     NaN       NaN    NaN   NaN
# ..     ...                      ...    ...     ...       ...    ...   ...
# 795    NaN                  Zoroark    NaN     NaN       NaN    NaN   NaN
# 796    NaN                    Zorua    NaN     NaN       NaN    NaN   NaN
# 797    NaN                    Zubat    NaN     NaN       NaN    NaN   NaN
# 798    NaN                 Zweilous    NaN     NaN       NaN    NaN   NaN
# 799    NaN         Zygarde50% Forme    NaN     NaN       NaN    NaN   NaN
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation new-total
# ...

# %%
df.dtypes
df
# Out:
#        #                     Name Type 1    Type 2  Legendary  Total  HP  \
# 139  129                 Magikarp  Water       NaN      False    200  20
# 381  349                   Feebas  Water       NaN      False    200  20
# 97    90                 Shellder  Water       NaN      False    305  30
# 106   98                   Krabby  Water       NaN      False    325  30
# 125  116                   Horsea  Water       NaN      False    295  30
# ..   ...                      ...    ...       ...        ...    ...  ..
# 232  214  HeracrossMega Heracross    Bug  Fighting      False    600  80
# 678  617                 Accelgor    Bug       NaN      False    495  80
# 734  666                 Vivillon    Bug    Flying      False    411  80
# 698  637                Volcarona    Bug      Fire      False    550  85
# 520  469                  Yanmega    Bug    Flying      False    515  86
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation new-total
# ...

# %%
df.loc[(df['Attack']>=100) & (df['Total'] > 600), 'Legendary']=True
df
# Out:
#        #                     Name Type 1    Type 2  Legendary  Total  HP  \
# 139  129                 Magikarp  Water       NaN      False    200  20
# 381  349                   Feebas  Water       NaN      False    200  20
# 97    90                 Shellder  Water       NaN      False    305  30
# 106   98                   Krabby  Water       NaN      False    325  30
# 125  116                   Horsea  Water       NaN      False    295  30
# ..   ...                      ...    ...       ...        ...    ...  ..
# 232  214  HeracrossMega Heracross    Bug  Fighting      False    600  80
# 678  617                 Accelgor    Bug       NaN      False    495  80
# 734  666                 Vivillon    Bug    Flying      False    411  80
# 698  637                Volcarona    Bug      Fire      False    550  85
# 520  469                  Yanmega    Bug    Flying      False    515  86
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation new-total
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(x='Total', data=df)
plt.show()

# %%
print(df.head())
# Out:
#        #      Name Type 1 Type 2  Legendary  Total  HP  Attack  Defense  \
# 139  129  Magikarp  Water    NaN      False    200  20      10       55
# 381  349    Feebas  Water    NaN      False    200  20      15       20
# 97    90  Shellder  Water    NaN      False    305  30      65      100
# 106   98    Krabby  Water    NaN      False    325  30     105       90
# 125  116    Horsea  Water    NaN      False    295  30      40       70
#
#      Sp. Atk  Sp. Def  Speed  Generation new-total
# 139       15       20     80           1       300
# 381       10       55     80           3       265
# 97        45       25     40           1       545
# 106       25       25     50           1       575
# 125       70       25     60           1       505

# %%
sns.displot(df['Total'])
plt.show()

# %%
df.groupby(['Type 1', 'Legendary'])['Total'].mean().plot.bar()
plt.show()

# %%
sns.barplot(y='Type 1', x='Total', hue='Legendary', data=df)
# Out:
# <Axes: xlabel='Total', ylabel='Type 1'>

# %%
plt.show()

# %%
df.groupby('Type 1')['Name'].count().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Type 1'>

# %%
plt.show()

# %%
sns.boxplot(y='Type 1', x='Total', hue='Legendary', data=df)
# Out:
# <Axes: xlabel='Total', ylabel='Type 1'>

# %%
plt.show()

# %%
sns.countplot(y='Type 1', data=df)
# Out:
# <Axes: xlabel='count', ylabel='Type 1'>

# %%
plt.show()

# %%
sns.boxplot(y='Type 1', x='Total', hue='Legendary', data=df, palette='rainbow')
# Out:
# <Axes: xlabel='Total', ylabel='Type 1'>

# %%
plt.show()
